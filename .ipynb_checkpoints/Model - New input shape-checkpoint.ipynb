# %%
import pandas as pd
import numpy as np
import numpy
import matplotlib.pyplot as plt
import os
import glob

# %%
df_train = pd.read_pickle('df_train')
df_test = pd.read_pickle('df_test')
del(df_train['DateTime'])

# %%
std = {'W': 1.5e5, 'HiT': 5, 'LoT' : 5}

# %%
df_train['W'].mean()
# Out:
# 562629.0730947304

# %%
df_train['W'] = df_train['W'] / std['W']
for param in ['HiT', 'LoT']:
    df_train[param] = df_train[param] / std[param]
    df_test[param] = df_test[param] / std[param]

# %%
df_train
# Out:
#              W  HiT  LoT  isWeekend
# 0     3.463985  6.0  3.6          0
# 1     3.322316  6.0  3.6          0
# 2     3.228695  6.0  3.6          0
# 3     3.109198  6.0  3.6          0
# 4     3.237810  6.0  3.6          0
# 5     3.122625  6.0  3.6          0
# 6     2.610293  6.0  3.6          0
# 7     2.879477  6.0  3.6          0
# 8     3.389768  6.0  3.6          0
# 9     4.812751  6.0  3.6          0
# 10    5.289655  6.0  3.6          0
# 11    5.141343  6.0  3.6          0
# 12    5.526908  6.0  3.6          0
# 13    5.151816  6.0  3.6          0
# 14    4.930735  6.0  3.6          0
# 15    5.219530  6.0  3.6          0
# 16    4.863530  6.0  3.6          0
# 17    4.714960  6.0  3.6          0
# 18    4.559728  6.0  3.6          0
# 19    4.334817  6.0  3.6          0
# 20    4.184715  6.0  3.6          0
# 21    4.044635  6.0  3.6          0
# 22    3.935146  6.0  3.6          0
# 23    3.622731  6.0  3.6          0
# 24    3.440633  6.4  3.6          0
# 25    3.274538  6.4  3.6          0
# 26    3.185594  6.4  3.6          0
# 27    3.118055  6.4  3.6          0
# 28    3.154375  6.4  3.6          0
# 29    3.052466  6.4  3.6          0
# ...        ...  ...  ...        ...
# 1818  6.943750  3.8  1.8          0
# 1819  6.545413  3.8  1.8          0
# 1820  6.307789  3.8  1.8          0
# 1821  6.215786  3.8  1.8          0
# 1822  6.272914  3.8  1.8          0
# 1823  5.965230  3.8  1.8          0
# 1824  5.654907  3.4  1.6          0
# 1825  5.218493  3.4  1.6          0
# 1826  4.921540  3.4  1.6          0
# 1827  4.909021  3.4  1.6          0
# 1828  4.759489  3.4  1.6          0
# 1829  4.949052  3.4  1.6          0
# 1830  4.771395  3.4  1.6          0
# 1831  4.582617  3.4  1.6          0
# 1832  5.599603  3.4  1.6          0
# 1833  6.256426  3.4  1.6          0
# 1834  6.733124  3.4  1.6          0
# 1835  6.708533  3.4  1.6          0
# 1836  6.695493  3.4  1.6          0
# 1837  6.419834  3.4  1.6          0
# 1838  6.024301  3.4  1.6          0
# 1839  5.988680  3.4  1.6          0
# 1840  5.862726  3.4  1.6          0
# 1841  6.210493  3.4  1.6          0
# 1842  6.526997  3.4  1.6          0
# 1843  6.586719  3.4  1.6          0
# 1844  6.262180  3.4  1.6          0
# 1845  6.196034  3.4  1.6          0
# 1846  6.388007  3.4  1.6          0
# 1847  6.171583  3.4  1.6          0
#
# [1848 rows x 4 columns]

# %%
plt.plot(df_train['W'][:])
plt.show()

# %%
df_train['W'][326:393].mean()
# Out:
# 1.5103111618364438

# %%
df_train['W'][326:396] += df_train['W'][0:1500].mean() - df_train['W'][326:393].mean()
# Out:
# /Users/Muks/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
plt.plot(df_train['W'][:])
plt.show()

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back)]
		dataX.append(a)
		dataY.append(dataset[i + look_back, :, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
dataset = df_train.values.reshape((-1, 24, 4))

# %%
dataset.shape
# Out:
# (77, 24, 4)

# %%
X, y = create_dataset(dataset, look_back=7)
X = X.reshape((X.shape[0], -1, 4))

# %%
X.shape, y.shape
# Out:
# ((70, 168, 4), (70, 24))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Input
from keras.optimizers import adagrad, adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(100, input_shape=(7 * 24, 4)))
model.add(Dense(50, activation='relu'))
model.add(Dense(24))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               42000
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                1224
# =================================================================
# Total params: 48,274
# Trainable params: 48,274
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile(loss='mean_squared_error', optimizer=adagrad(lr=0.01))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
num_train = 64
X_train = X[ : num_train]
y_train = y[ : num_train]
X_test = X[num_train : ]
y_test = y[num_train : ]

# %%
model.fit(X_train, y_train, epochs=80, batch_size=4)
# Out:
# Epoch 1/80
# 64/64 [==============================] - 10s - loss: 9.9530
# Epoch 2/80
# 64/64 [==============================] - 10s - loss: 4.1779
# Epoch 3/80
# 64/64 [==============================] - 8s - loss: 1.7706
# Epoch 4/80
# 64/64 [==============================] - 8s - loss: 0.8721
# Epoch 5/80
# 64/64 [==============================] - 8s - loss: 0.5924
# Epoch 6/80
# 64/64 [==============================] - 8s - loss: 0.5549
# Epoch 7/80
# 64/64 [==============================] - 8s - loss: 0.5293
# Epoch 8/80
# 64/64 [==============================] - 8s - loss: 0.5562
# Epoch 9/80
# 64/64 [==============================] - 8s - loss: 0.5234
# Epoch 10/80
# 64/64 [==============================] - 8s - loss: 0.5224
# Epoch 11/80
# 64/64 [==============================] - 8s - loss: 0.4919
# Epoch 12/80
# 64/64 [==============================] - 8s - loss: 0.4802
# Epoch 13/80
# 64/64 [==============================] - 10s - loss: 0.4473
# Epoch 14/80
# 64/64 [==============================] - 9s - loss: 0.4516
# Epoch 15/80
# 64/64 [==============================] - 9s - loss: 0.3975
# Epoch 16/80
# 64/64 [==============================] - 9s - loss: 0.3342
# Epoch 17/80
# 64/64 [==============================] - 9s - loss: 0.2838
# Epoch 18/80
# 64/64 [==============================] - 9s - loss: 0.2357
# Epoch 19/80
# 64/64 [==============================] - 10s - loss: 0.4409
# Epoch 20/80
# 64/64 [==============================] - 9s - loss: 0.3596
# Epoch 21/80
# 64/64 [==============================] - 9s - loss: 0.2641
# Epoch 22/80
# 64/64 [==============================] - 9s - loss: 0.2161
# Epoch 23/80
# 64/64 [==============================] - 10s - loss: 0.2703
# Epoch 24/80
# 64/64 [==============================] - 9s - loss: 0.1952
# Epoch 25/80
# 64/64 [==============================] - 10s - loss: 0.1843
# Epoch 26/80
# 64/64 [==============================] - 10s - loss: 0.1784
# Epoch 27/80
# 64/64 [==============================] - 10s - loss: 0.1655
# Epoch 28/80
# 64/64 [==============================] - 11s - loss: 0.2313
# Epoch 29/80
# 64/64 [==============================] - 10s - loss: 0.1530
# Epoch 30/80
# 64/64 [==============================] - 9s - loss: 0.1604
# Epoch 31/80
# 64/64 [==============================] - 9s - loss: 0.1458
# Epoch 32/80
# 64/64 [==============================] - 10s - loss: 0.1593
# Epoch 33/80
# 64/64 [==============================] - 10s - loss: 0.1494
# Epoch 34/80
# 64/64 [==============================] - 10s - loss: 0.1543
# Epoch 35/80
# 64/64 [==============================] - 10s - loss: 0.1605
# Epoch 36/80
# 64/64 [==============================] - 10s - loss: 0.1445
# Epoch 37/80
# 64/64 [==============================] - 11s - loss: 0.1712
# Epoch 38/80
# 64/64 [==============================] - 10s - loss: 0.1451
# Epoch 39/80
# 64/64 [==============================] - 9s - loss: 0.1307
# Epoch 40/80
# 64/64 [==============================] - 9s - loss: 0.1403
# Epoch 41/80
# 64/64 [==============================] - 9s - loss: 0.1706
# Epoch 42/80
# 64/64 [==============================] - 9s - loss: 0.1434
# Epoch 43/80
# 64/64 [==============================] - 9s - loss: 0.1840
# Epoch 44/80
# 64/64 [==============================] - 9s - loss: 0.1812
# Epoch 45/80
# 64/64 [==============================] - 9s - loss: 0.1474
# Epoch 46/80
# 64/64 [==============================] - 9s - loss: 0.1332
# Epoch 47/80
# 64/64 [==============================] - 8s - loss: 0.1330
# Epoch 48/80
# 64/64 [==============================] - 9s - loss: 0.1179
# Epoch 49/80
# 64/64 [==============================] - 9s - loss: 0.1193
# Epoch 50/80
# 64/64 [==============================] - 9s - loss: 0.1092
# Epoch 51/80
# 64/64 [==============================] - 9s - loss: 0.1097
# Epoch 52/80
# 64/64 [==============================] - 8s - loss: 0.1228
# Epoch 53/80
# 64/64 [==============================] - 8s - loss: 0.1215
# Epoch 54/80
# 64/64 [==============================] - 8s - loss: 0.1423
# Epoch 55/80
# 64/64 [==============================] - 8s - loss: 0.1209
# Epoch 56/80
# 64/64 [==============================] - 8s - loss: 0.1266
# Epoch 57/80
# 64/64 [==============================] - 8s - loss: 0.1237
# Epoch 58/80
# 64/64 [==============================] - 8s - loss: 0.1197
# Epoch 59/80
# 64/64 [==============================] - 8s - loss: 0.1158
# Epoch 60/80
# 64/64 [==============================] - 8s - loss: 0.1115
# Epoch 61/80
# 64/64 [==============================] - 8s - loss: 0.1066
# Epoch 62/80
# 64/64 [==============================] - 8s - loss: 0.1039
# Epoch 63/80
# 32/64 [==============>...............] - ETA: 4s - loss: 0.1112
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-77f08afacafd> in <module>()
# ----> 1 model.fit(X_train, y_train, epochs=80, batch_size=4)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# model.fit(X_train, y_train, epochs=80, batch_size=4)
# Out:
# Epoch 1/80
# 64/64 [==============================] - 8s - loss: 10.6483
# Epoch 2/80
# 64/64 [==============================] - 7s - loss: 4.5257
# Epoch 3/80
# 64/64 [==============================] - 7s - loss: 1.5207
# Epoch 4/80
# 64/64 [==============================] - 7s - loss: 0.8209
# Epoch 5/80
# 64/64 [==============================] - 7s - loss: 0.7809
# Epoch 6/80
# 64/64 [==============================] - 7s - loss: 0.7667
# Epoch 7/80
# 64/64 [==============================] - 7s - loss: 0.7242
# Epoch 8/80
# 64/64 [==============================] - 7s - loss: 0.2692
# Epoch 52/80
# 64/64 [==============================] - 7s - loss: 0.2508
# Epoch 53/80
# 64/64 [==============================] - 7s - loss: 0.2339
# Epoch 54/80
# 64/64 [==============================] - 7s - loss: 0.2122
# Epoch 55/80
# 64/64 [==============================] - 8s - loss: 0.1932
# Epoch 56/80
# 64/64 [==============================] - 8s - loss: 0.1915
# Epoch 57/80
# 64/64 [==============================] - 7s - loss: 0.1949
# Epoch 58/80
# 64/64 [==============================] - 7s - loss: 0.1888
# Epoch 59/80
# 64/64 [==============================] - 8s - loss: 0.1908
# Epoch 60/80
# 64/64 [==============================] - 7s - loss: 0.1957
# Epoch 61/80
# 64/64 [==============================] - 7s - loss: 0.1967
# Epoch 62/80
# 64/64 [==============================] - 7s - loss: 0.1912
# Epoch 63/80
# 64/64 [==============================] - 7s - loss: 0.1868
# Epoch 64/80
# 64/64 [==============================] - 7s - loss: 0.1813
# Epoch 65/80
# 64/64 [==============================] - 7s - loss: 0.1870
# Epoch 66/80
# 64/64 [==============================] - 7s - loss: 0.1778
# Epoch 67/80
# 64/64 [==============================] - 9s - loss: 0.2008
# Epoch 68/80
# 64/64 [==============================] - 8s - loss: 0.1814
# Epoch 69/80
# 64/64 [==============================] - 8s - loss: 0.1815
# Epoch 70/80
# 64/64 [==============================] - 8s - loss: 0.1781
# Epoch 71/80
# 32/64 [==============>...............] - ETA: 4s - loss: 0.2090
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-77f08afacafd> in <module>()
# ----> 1 model.fit(X_train, y_train, epochs=80, batch_size=4)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Users/Muks/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
y_pred = model.predict(X)

# %%
plt.plot(y_pred.flatten()[-300:])
plt.plot(y.flatten()[-300:])
plt.show()

# %%
plt.plot(y_pred.flatten()[-20*24:-19*24])
plt.plot(y.flatten()[-20*24:-19*24])
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s
# 0.32002928853034973

# %%
model.compile(loss='mean_squared_error', optimizer=adagrad(lr=0.1))

# %%
model.save_weights('model_weights.h5')

# %%
# create and fit the LSTM network
model2 = Sequential()
model2.add(LSTM(100, input_shape=(7 * 24, 4)))
model2.add(Dense(50, activation='relu'))
model2.add(Dense(24))
model2.compile(loss='mean_squared_error', optimizer='adam')
model2.load_weights('model_weights.h5')

# %%
model2.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s
# 0.32002928853034973

# %%
X[-1].shape, y[-1].shape
# Out:
# ((168, 4), (24,))

# %%
df_test
# Out:
#      HiT  LoT  isWeekend
# 0    3.4  1.4          0
# 1    3.4  1.4          0
# 2    3.4  1.4          0
# 3    3.4  1.4          0
# 4    3.4  1.4          0
# 5    3.4  1.4          0
# 6    3.4  1.4          0
# 7    3.4  1.4          0
# 8    3.4  1.4          0
# 9    3.4  1.4          0
# 10   3.4  1.4          0
# 11   3.4  1.4          0
# 12   3.4  1.4          0
# 13   3.4  1.4          0
# 14   3.4  1.4          0
# 15   3.4  1.4          0
# 16   3.4  1.4          0
# 17   3.4  1.4          0
# 18   3.4  1.4          0
# 19   3.4  1.4          0
# 20   3.4  1.4          0
# 21   3.4  1.4          0
# 22   3.4  1.4          0
# 23   3.4  1.4          0
  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 5.63685091,  3.2       ,  1.2       ,  1.        ],
#        [ 2.83829966,  3.2       ,  1.2       ,  1.        ],
#        [ 5.4771246 ,  3.2       ,  1.2       ,  1.        ],
#        [ 5.77264878,  3.2       ,  1.2       ,  1.        ],
#        [ 5.14947525,  3.8       ,  1.8       ,  0.        ],
#        [ 4.876612  ,  3.8       ,  1.8       ,  0.        ],
#        [ 4.6110287 ,  3.8       ,  1.8       ,  0.        ],
#        [ 4.42573967,  3.8       ,  1.8       ,  0.        ],
#        [ 4.36787122,  3.8       ,  1.8       ,  0.        ],
#        [ 4.377243  ,  3.8       ,  1.8       ,  0.        ],
#        [ 4.37577582,  3.8       ,  1.8       ,  0.        ],
#        [ 4.26090633,  3.8       ,  1.8       ,  0.        ],
#        [ 4.78326222,  3.8       ,  1.8       ,  0.        ],
#        [ 5.57336733,  3.8       ,  1.8       ,  0.        ],
#        [ 6.33715898,  3.8       ,  1.8       ,  0.        ],
#        [ 6.53375633,  3.8       ,  1.8       ,  0.        ],
#        [ 6.646525  ,  3.8       ,  1.8       ,  0.        ],
#        [ 6.45902711,  3.8       ,  1.8       ,  0.        ],
#        [ 6.32050621,  3.8       ,  1.8       ,  0.        ],
#        [ 6.03665356,  3.8       ,  1.8       ,  0.        ],
#        [ 6.10088711,  3.8       ,  1.8       ,  0.        ],
#        [ 6.57347622,  3.8       ,  1.8       ,  0.        ],
#        [ 6.94374983,  3.8       ,  1.8       ,  0.        ],
#        [ 6.54541311,  3.8       ,  1.8       ,  0.        ],
#        [ 6.307789  ,  3.8       ,  1.8       ,  0.        ],
#        [ 6.21578622,  3.8       ,  1.8       ,  0.        ],
#        [ 6.27291356,  3.8       ,  1.8       ,  0.        ],
#        [ 5.96522989,  3.8       ,  1.8       ,  0.        ]])

# %%
X[-1].shape
# Out:
# (168, 4)

# %%
testData = df_test.values

# %%
testData.shape
# Out:
# (264, 3)

# %%
testData
# Out:
# array([[ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.4,  1.4,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.6,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.8,  1.4,  0. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 3.6,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.6,  1. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 4.4,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  1.4,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 5. ,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 4.6,  2. ,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 3.6,  2.2,  0. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ],
#        [ 4.6,  1.6,  1. ]])

# %%
X_prev = X[-1:]
y_prev = model.predict(X_prev)

# %%
y_prev.shape
# Out:
# (1, 24)

# %%
i = 0
# testData[i*24: (i+1)*24].shape
y_prev = model.predict(X_prev)
y_prev.T.shape
# Out:
# (24, 1)

# %%
testData[i*24: (i+1)*24].shape
# Out:
# (24, 3)

# %%
X_add = np.concatenate((y_prev.T, testData[i*24: (i+1)*24]), axis=1).reshape((1, 24, 4))

# %%
X_prev[:, 24:].shape
# Out:
# (1, 144, 4)

# %%
np.concatenate((X_prev[:, 24:], X_add), axis=1).shape
# Out:
# (1, 168, 4)

# %%
to_predict = 7
X_prev = X[-1:]
preds = []
for i in range(to_predict):
    y_prev = model.predict(X_prev)
    preds.append(y_prev)
    X_add = np.concatenate((y_prev.T, testData[i*24: (i+1)*24]), axis=1).reshape((1, 24, 4))
    X_prev = np.concatenate((X_prev[:, 24:], X_add), axis=1)

# %%
preds = np.asarray(preds).flatten()

# %%
plt.plot(preds)
plt.show()
